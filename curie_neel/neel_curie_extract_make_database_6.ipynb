# %%
from chemdataextractor_neel_curie import Document
from chemdataextractor_neel_curie.model import Compound
from chemdataextractor_neel_curie.doc import Paragraph, Heading, Title
from chemdataextractor.scrape import Selector
from chemdataextractor.scrape.pub.rsc import RscHtmlDocument

import os
import glob
import timeit
import pandas as pd
import collections

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Ayan Deep Hazra\\Desktop\\Python\\CDE_MSE_Databases\\curie_neel'

# %%
all_extracted_json = [] # store for database
start = timeit.default_timer()

# read all html papers
i = 0
for file in glob.glob("./papers2/*.html"):
    
    #open file
    f = open(file, 'rb')
    doc = Document.from_file(f)  
    extracted_json = doc.records.serialize()#extract records # return list of dict
    for dic in extracted_json:
        print(dic)
    # Option1: if there is name and temperature extracted together
    name_temp_ls = [dc for dc in extracted_json if (('names' in dc) and ('curie_temperatures' in dc)) or (('names' in dc) and ('neel_temperatures' in dc))]

    # Option2: if temperature and name are separately extracted
    temp = [dc for dc in extracted_json if ('neel_temperatures' in dc) or ('curie_temperatures' in dc)] 
    roles = [dc for dc in extracted_json if ('roles' in dc) and (dc not in name_temp_ls)]

    #printing and storing information
    if name_temp_ls or (temp and roles): #either Option1 or Option2 is True
        

        #MetaData author, paper citations
        htmlstring = open(file,'rb').read()
        sel = Selector.from_text(htmlstring)
        scrape = RscHtmlDocument(sel)
        somedc = scrape.serialize()
        citation_dc = {'doi': somedc['doi'], 'publisher': scrape.publisher, 'title': somedc['title'], 'authors': somedc['authors'], 'filename': file} #keep only these keys
        title = somedc['title']

        print(f'{i}.\nfilename: {file}')
        print(f'Title: {title}\n')

        if name_temp_ls: # if Option 1 is True print and store Option 1
            temporary_ls = []

            for nt in name_temp_ls:
                print(nt)
                temporary_ls.append(nt)

            for r in roles: # some have exception
                print(r)
                temporary_ls.append(r)

            temporary_ls.append(citation_dc)
            all_extracted_json.append(temporary_ls)#store for database


        elif temp and roles: # if Option 2 is True print and store Option 2
            temporary_ls = []

            for r in roles: #print all names extracted with 'roles', but no temperature
                print(r)
                temporary_ls.append(r)
            for t in temp: #print all temperatures extracted, but no name proceeding it
                print(t)
                temporary_ls.append(t)

            temporary_ls.append(citation_dc)
            all_extracted_json.append(temporary_ls)#store for database

    print("----------------------------")
    i += 1
    
    if i == 25:################### testing first 50 papers
        break

stop = timeit.default_timer()
print('Run Time: ', stop - start, ' seconds')
# Out:
# {'names': ['CICECO']}
# {'names': ['F-94320 Thiais']}
# {'names': ['AFe2O4']}
# {'names': ['transition metal']}
# {'names': ['Cr']}
# {'names': ['Co']}
# {'names': ['16 trivalent iron']}
# {'names': ['(M2+)A[Fe3+]BO4']}
# {'names': ['(Fe3+)A[M2+Fe3+]BO4']}
# {'names': ['( JA–A and JB–B ) lead']}
# {'names': ['( JA–B )']}
# {'names': ['(Fei3+M1−i2+)[Mi2+Fe2−i3+]O4']}
# {'names': ['FeA']}
# {'names': ['O–FeB']}
# {'names': ['aluminum']}
# {'names': ['nickel']}
# {'names': ['iron']}
# {'names': ['Li']}
# {'names': ['Co ferrite']}
# {'names': ['nickel–zinc ferrites']}
# {'names': ['Fe(NO3)3·9H2O']}
# {'names': ['NiCl2·6H2O']}
# {'names': ['oxides']}
# {'names': ['ZnO']}
# {'names': ['Al2O3']}
# {'names': ['nitric acid']}
# {'names': ['citric acid']}
# {'names': ['C6H8O7']}
# {'names': ['ethylene glycol']}
# {'names': ['C2H6O2']}
# {'names': ['nitrogen']}
# {'names': ['silver']}
# {'names': ['nitrate']}
# {'names': ['citrate acid']}
# {'names': ['metal oxide']}
# {'names': ['ferrite Ni0.6Zn0.4Al0.5Fe1.5O4']}
# {'names': ['NiO']}
# {'names': ['( S5–S13 )', 'ESI']}
# {'names': ['Co3O4']}
# {'names': ['Ni0.6Zn0.4Al0.5Fe1.5O4 ferrite']}
# {'names': ['Ni1050']}
# {'names': ['3T2g + 2A2u + 2Eu + 4T1u(IR) + 2T2u']}
# {'names': ['α-Fe2O3']}
# {'names': ['iron oxide']}
# {'names': ['AO4']}
# {'names': ['Ni–O']}
# {'names': ['Zn–O']}
# {'names': ['Al–O']}
# {'names': ['Si']}
# {'names': ['GaAs']}
# {'names': ['FeO6']}
# {'names': ['FeO4']}
# {'names': ['C11 = C12']}
# {'names': ['Mg']}
# {'names': ['Cv']}
# {'names': ['Einstein']}
# {'names': ['A2+B23+O4']}
# {'names': ['nickel–zinc ferrite']}
# {'names': ['( b–f )']}
# {'names': ['magnesium']}
# {'curie_temperatures': [{'value': '>800', 'units': 'K'}]}
# {'curie_temperatures': [{'value': '663', 'units': 'K'}]}
# {'names': ['– A, B–B']}
# {'names': ['Avogadro']}
# {'names': ['perovskite']}
# {'names': ['La1−xSrxMnO3']}
# {'names': ['NZAFO']}
# {'names': ['Δ H']}
# {'curie_temperatures': [{'value': '540', 'units': 'K'}]}
# {'names': ['Ni3+']}
# {'names': ['lithium']}
# {'names': ['A-site']}
# {'names': ['B-site']}
# {'names': ['M2+']}
# {'names': ['polyol']}
# {'names': ['octahedral B']}
# {'names': ['Zn2+']}
# {'names': ['Ni0.4Zn0.2Mn0.4Fe2O4']}
# {'names': ['argon']}
# {'names': ['metal oxides']}
# {'names': ['hematite']}
# {'names': ['Fe–O']}
# {'names': ['Cu']}
# {'names': ['ZnFe2O4']}
# {'names': ['nickel ferrite']}
# {'names': ['Ni0.6Zn0.4Fe2O4']}
# {'names': ['Ni0.5Zn0.5Fe2O4']}
# {'names': ['manganite']}
# {'names': ['Fe2O3']}
# {'names': ['CoFe2O4']}
# {'names': ['H']}
# {'names': ['Zn ferrite']}
# {'names': ['Mn']}
# {'names': ['Al3+']}
# {'names': ['Ni0.6Zn0.4Al0.5Fe1.5O4']}
# {'names': ['O']}
# {'names': ['Fe']}
# {'names': ['NiFe2O4'], 'curie_temperatures': [{'value': '883', 'units': 'K'}]}
# {'names': ['Ni2+']}
# {'names': ['Fe2+']}
# {'names': ['oxygen']}
# {'names': ['Fe3+']}
# {'names': ['Al']}
# {'names': ['Al ferrite']}
# {'names': ['ferrites']}
# {'names': ['NZFAO', 'Ni0.6Zn0.4Fe1.5Al0.5O4']}
# {'names': ['ferrite']}
# {'names': ['Zn']}
# {'names': ['Ni']}
# 0.
# filename: ./papers2\curie_paper1.html
# Title: Magnetic and spectroscopic properties of Ni–Zn–Al ferrite spinel: from the nanoscale to microscale
#
# {'names': ['NiFe2O4'], 'curie_temperatures': [{'value': '883', 'units': 'K'}]}
# ----------------------------
# {'names': ['S']}
# {'names': ['O']}
# {'names': ['Vladimirskaya']}
# {'names': ['Ga-substituted hexaferrites']}
# {'names': ['BaFe12O19 barium ferrite']}
# {'names': ['In3+']}
# {'names': ['PbO·6Fe2O3 magnetoplumbite']}
# {'curie_temperatures': [{'value': '∼740', 'units': 'K'}]}
# {'names': ['Mn2+']}
# {'names': ['Ga']}
# {'names': ['Sc']}
# {'names': ['BaFe12O19 hexaferrites']}
# {'names': ['Fe2O3']}
# {'names': ['Ga2O3 oxides']}
# {'names': ['BaCO3 carbonate']}
# {'names': ['Helium']}
# {'names': ['Fe1–2a, Fe4–4fVI']}
# {'names': ['Fe5–12k']}
# {'names': ['( Fe3–4fIV ) and bipiramidal']}
# {'names': ['( Fe2–2b ) oxygen']}
# {'names': ['Ba2+']}
# {'names': ['Fe4–O5 and Fe5–O1']}
# {'names': ['Fe5–O2–Fe5 and Fe5–O4–Fe5']}
# {'names': ['Fe4–O5']}
# {'names': ['Fe5–O1']}
# {'names': ['Fe5–O2–Fe5']}
# {'names': ['Fe5–O4–Fe5']}
# {'names': ['Al2O3']}
# {'names': ['BaFe12−xInxO19']}
# {'names': ['O2− anions']}
# {'names': ['O2−']}
# {'names': ['ferrimagnetic hexaferrite']}
# {'names': ['Fe3+ O2−']}
# {'names': ['= A*x2 + B*x + C']}
# {'names': ['ferro- or ferrimagnets']}
# {'names': ['Zn2+']}
# {'names': ['Cr3+']}
# {'names': ['Ti3+']}
# {'names': ['Co3+']}
# {'names': ['= fres(0) + A*x2 + B*x']}
# {'names': ['bipyramidal']}
# {'names': ['NITU']}
# {'names': ['Ukraine']}
# {'names': ['strontium']}
# {'names': ['Sc3+']}
# {'names': ['Co2+']}
# {'names': ['Ti4+']}
# {'names': ['Al']}
# {'names': ['ferrites']}
# {'names': ['oxides']}
# {'names': ['Fe2–O3']}
# {'names': ['Fe3–O2']}
# {'names': ['Fe1–O4']}
# {'names': ['Fe2–O1']}
# {'names': ['Fe3–O4']}
# {'names': ['Fe4–O3']}
# {'names': ['Fe5–O2']}
# {'names': ['Fe2–O3–Fe4']}
# {'names': ['Fe3–O4–Fe5']}
# {'names': ['Fe4–O3–Fe4']}
# {'names': ['Fe5–O1–Fe5']}
# {'names': ['gallium']}
# {'names': ['BaFe12O19'], 'curie_temperatures': [{'value': '740', 'units': 'K'}]}
# {'names': ['H']}
# {'names': ['Al3+']}
# {'names': ['iron']}
# {'names': ['barium hexaferrite']}
# {'names': ['fres(x)', 'fres(0) + A*x2']}
# {'names': ['hexaferrite']}
# {'names': ['barium']}
# {'names': ['Fe3+–O2−–Fe3+']}
# {'names': ['oxygen']}
# {'names': ['BaFe12−xGaxO19']}
# {'names': ['Fe3+']}
# {'names': ['Ga3+']}
# 1.
# filename: ./papers2\curie_paper10.html
# Title: Investigation into the structural features and microwave absorption of doped barium hexaferrites
#
# {'names': ['BaFe12O19'], 'curie_temperatures': [{'value': '740', 'units': 'K'}]}
# ----------------------------
# {'names': ['ETM']}
# {'names': ['Dopant']}
# {'names': ['Sc']}
# {'names': ['Eb']}
# {'names': ['Easy axis']}
# {'names': ['− 430']}
# {'names': ['− 576']}
# {'names': ['− 83']}
# {'names': ['− 98']}
# {'names': ['− 18']}
# {'names': ['− 22']}
# {'names': ['− 1']}
# {'names': ['− 7']}
# {'names': ['− 15']}
# {'names': ['− 16']}
# {'names': ['− 45']}
# {'names': ['− 99']}
# {'names': ['− 23']}
# {'names': ['− 33']}
# {'names': ['− 70']}
# {'names': ['− 36']}
# {'names': ['− 21']}
# {'names': ['− 47']}
# {'names': ['− 41']}
# {'names': ['− 0.5']}
# {'names': ['− 9']}
# {'names': ['− 10']}
# {'names': ['plumbene oscillate']}
# {'names': ['transition metal', 'TM']}
# {'names': ['graphene']}
# {'names': ['transition-metal dichalcogenides', 'TMDs', 'transition - metal dichalcogenides']}
# {'names': ['phosphorene']}
# {'names': ['− 125']}
# {'names': ['− 78']}
# {'names': ['− 12']}
# {'names': ['− 5']}
# {'names': ['− 34']}
# {'names': ['Ni']}
# {'names': ['K']}
# {'names': ['Cr']}
# {'names': ['Co']}
# {'names': ['Ti']}
# {'names': ['Pb']}
# {'names': ['Fe']}
# {'names': ['Mn']}
# {'names': ['plumbene'], 'roles': ['product'], 'curie_temperatures': [{'value': '300', 'units': 'K'}]}
# 2.
# filename: ./papers2\curie_paper101.html
# Title: Magnetic properties of 3d transition metal (Sc–Ni) doped plumbene
#
# {'names': ['plumbene'], 'roles': ['product'], 'curie_temperatures': [{'value': '300', 'units': 'K'}]}
# ----------------------------
# {'names': ['Nanjing 210093']}
# {'names': ['heterometallic formate']}
# {'names': ['perovskite ABO3']}
# {'names': ['HCOO−']}
# {'names': ['ferro-']}
# {'names': ['PD-DMACoF']}
# {'names': ['DMA']}
# {'names': ['perdeuterodimethylammonium']}
# {'names': ['iron(III)']}
# {'names': ['iron(II) formate']}
# {'names': ['[DMFeFe]']}
# {'names': ['perovskite']}
# {'names': ['silicon nitride']}
# {'names': ['N']}
# {'names': ['FeCl2·4H2O']}
# {'names': ['dimethylformamide', 'DMF']}
# {'names': ['formic acid']}
# {'names': ['Teflon']}
# {'names': ['NiCl2·6H2O']}
# {'names': ['graphite']}
# {'names': ['non-hydrogen']}
# {'names': ['hydrogen']}
# {'names': ['η2-formate']}
# {'names': ['NiAs']}
# {'names': ['CaAlF6']}
# {'names': ['oxygen']}
# {'names': ['Me2NH2+']}
# {'names': ['Cr3+']}
# {'names': ['Cr2']}
# {'names': ['formate-bridged Cr1 ⋯ Fe1']}
# {'names': ['Cr–O']}
# {'names': ['trans O']}
# {'names': ['O–FeII–O']}
# {'names': ['trans O–FeII–O']}
# {'names': ['nickel(II)']}
# {'names': ['iron(II)']}
# {'names': ['Ni2+']}
# {'names': ['perovskites']}
# {'names': ['[ 2ZS(S + 1 ) ]']}
# {'names': ['JCrFe']}
# {'names': ['nickel']}
# {'names': ['N–H']}
# {'names': ['CH3']}
# {'names': ['NaNO2']}
# {'names': ['nitric acid glycine']}
# {'names': ['[NH2(CH3)2][CrIIIMII(HCOO)6]']}
# {'names': ['Li']}
# {'names': ['DMFeFe']}
# {'names': ['CrCl3·6H2O']}
# {'names': ['C8H14CrFeNO12']}
# {'names': ['C8H14CrNiNO12']}
# {'names': ['H']}
# {'names': ['P1c(163)']}
# {'names': ['O']}
# {'names': ['Fe2+']}
# {'names': ['chromium(III)']}
# {'names': ['NiII']}
# {'names': ['chromium']}
# {'names': ['DMA+']}
# {'names': ['niccolite']}
# {'names': ['Cr']}
# {'names': ['Fe1']}
# {'names': ['FeII']}
# {'names': ['Ni', '[NH2(CH3)2][CrIIINiII(HCOO)6]'], 'labels': ['2'], 'roles': ['complex', 'data for'], 'curie_temperatures': [{'value': '15.3'}]}
# {'names': ['[NH2(CH3)2][CrIIIFeII(HCOO)6]', 'Fe'], 'labels': ['1'], 'roles': ['complex', 'data for']}
# {'names': ['formate']}
# 3.
# filename: ./papers2\curie_paper106.html
# Title: Study of the relationship between magnetic field and dielectric properties in two ferromagnetic complexes
#
# {'names': ['Ni', '[NH2(CH3)2][CrIIINiII(HCOO)6]'], 'labels': ['2'], 'roles': ['complex', 'data for'], 'curie_temperatures': [{'value': '15.3'}]}
# {'names': ['[NH2(CH3)2][CrIIIFeII(HCOO)6]', 'Fe'], 'labels': ['1'], 'roles': ['complex', 'data for']}
# ----------------------------
# {'names': ['Bath BA2 7AY']}
# {'names': ['hydrocarbon']}
# {'names': ['atmospheric CO2']}
# {'names': ['hydrocarbons']}
# {'names': ['formic acid', 'HCOOH']}
# {'names': ['ethylene']}
# {'names': ['C2H4']}
# {'names': ['C2H5OH']}
# {'names': ['pyro-electro-catalytic CO2']}
# {'names': ['Pb(ZrxTi1−x)O3']}
# {'names': ['Zr4+']}
# {'names': ['lead oxide']}
# {'names': ['zirconium dioxide']}
# {'names': ['ZrO2']}
# {'names': ['niobium oxide']}
# {'names': ['Nb2O5']}
# {'names': ['titanium dioxide']}
# {'names': ['TiO2']}
# {'names': ['poly(vinyl alcohol )', 'PVA']}
# {'names': ['α-Al2O3']}
# {'names': ['2550VB+']}
# {'names': ['Cu']}
# {'names': ['Pt']}
# {'names': ['Ir']}
# {'names': ['Si']}
# {'names': ['hydroxyl']}
# {'names': ['N2']}
# {'names': ['helium']}
# {'names': ['rsono-piezoi − rsono-chemicali']}
# {'names': ['dopant.Fig']}
# {'names': ['ferro-paraelectric']}
# {'names': ['metal oxides']}
# {'names': ['oxygen']}
# {'names': ['Ti–O']}
# {'names': ['Zr–O']}
# {'names': ['Ti 2p3']}
# {'names': ['( B ) O 1s, ( C ) Pb 4f, ( D ) Nb']}
# {'names': ['alumina']}
# {'names': ['sono-piezo']}
# {'names': ['barium strontium titanate']}
# {'names': ['Na2SO3 hydroxyl']}
# {'names': ['H2O + 2q+ → 2H+ + ½O2']}
# {'names': ['2H+ + 2q− → H2']}
# {'names': ['2H+ + 2q−']}
# {'names': ['doped lead zirconate titanate']}
# {'names': ['BaTiO3']}
# {'names': ['transition metals']}
# {'names': ['piezo']}
# {'names': ['carbon dioxide']}
# {'names': ['ethanol']}
# {'names': ['methane']}
# {'names': ['CH4']}
# {'names': ['Na2SO3']}
# {'names': ['argon']}
# {'names': ['Nb-doped lead zirconate titanate', 'Lead zirconate titanate', 'PZTN', 'lead zirconate titanate'], 'curie_temperatures': [{'value': '∼38', 'units': '°C'}]}
# {'names': ['Pb 4f7']}
# {'names': ['Pb2+']}
# {'names': ['Ti4+']}
# {'names': ['PTZN']}
# {'names': ['Bi2WO6']}
# {'names': ['H+']}
# {'names': ['O2']}
# {'names': ['H2O']}
# {'names': ['carbon', 'Carbon']}
# {'names': ['perovskite']}
# {'names': ['PZT']}
# {'names': ['Tc']}
# {'names': ['alpha-Al2O3']}
# {'names': ['O']}
# {'names': ['Ti']}
# {'names': ['Zr']}
# {'names': ['Al2O3']}
# {'names': ['Nb']}
# {'names': ['Pb'], 'labels': ['4f']}
# {'names': ['hydrogen', 'Hydrogen'], 'labels': ['H2'], 'roles': ['product'], 'curie_temperatures': [{'value': '∼39', 'units': '°C'}, {'value': '100', 'units': '°C'}, {'value': '∼38', 'units': '°C'}]}
# {'names': ['H2']}
# {'names': ['CO', 'carbon monoxide']}
# {'names': ['CO2']}
# 4.
# filename: ./papers2\curie_paper11.html
# Title: Polarisation tuneable piezo-catalytic activity of Nb-doped PZT with low Curie temperature for efficient CO2 reduction and H2 generation
#
# {'names': ['Nb-doped lead zirconate titanate', 'Lead zirconate titanate', 'PZTN', 'lead zirconate titanate'], 'curie_temperatures': [{'value': '∼38', 'units': '°C'}]}
# {'names': ['hydrogen', 'Hydrogen'], 'labels': ['H2'], 'roles': ['product'], 'curie_temperatures': [{'value': '∼39', 'units': '°C'}, {'value': '100', 'units': '°C'}, {'value': '∼38', 'units': '°C'}]}
# ----------------------------
# {'names': ['K. McBride']}
# {'names': ['La1−xSrxMnO3 –']}
# {'names': ['ferrites']}
# {'names': ['Pd–Ni']}
# {'names': ['Ni']}
# {'names': ['Cu']}
# {'names': ['Co']}
# {'names': ['Au']}
# {'names': ['Zn']}
# {'names': ['manganate']}
# {'names': ['perovskites']}
# {'names': ['metal oxides']}
# {'names': ['O2−']}
# {'names': ['Fe3O4']}
# {'names': ['metal oxide']}
# {'names': ['metal carbonate']}
# {'names': ['ammonium hydroxide']}
# {'names': ['EDTA']}
# {'names': ['citric acid']}
# {'names': ['chelating agents']}
# {'names': ['lanthanum(III) oxide']}
# {'names': ['manganese(II) carbonate']}
# {'names': ['strontium carbonate']}
# {'names': ['H2O']}
# {'names': ['ammonium hydroxide NH4OH']}
# {'names': ['manganese']}
# {'names': ['ammonia']}
# {'names': ['Mn2+']}
# {'names': ['carbon']}
# {'names': ['− 0.1']}
# {'names': ['O(2)']}
# {'names': ['O']}
# {'names': ['18e']}
# {'names': ['Aztec']}
# {'names': ['Sr']}
# {'names': ['cobalt']}
# {'names': ['MnCO3']}
# {'names': ['oxygen']}
# {'names': ['Sample name']}
# {'names': ['H', 'SQUID']}
# {'names': ['La0.8Sr0.2MnO3']}
# {'names': ['La0.6Sr0.4MnO3']}
# {'names': ['lanthanum']}
# {'names': ['Mn3+–O']}
# {'names': ['R w']}
# {'names': ['R bragg']}
# {'names': ['Tc']}
# {'names': ['Br']}
# {'names': ['Katherine McBride']}
# {'names': ['Belfast BT7 1NN'], 'curie_temperatures': [{'value': '89', 'units': '°C'}]}
# {'names': ['lanthanum strontium manganates']}
# {'names': ['iron']}
# {'names': ['Tcs']}
# {'names': ['manganates']}
# {'names': ['La0.7Sr0.3MnO3']}
# {'names': ['Mn3+–O2−–Mn4+']}
# {'names': ['La3+']}
# {'names': ['nitrate']}
# {'names': ['La2O3']}
# {'names': ['La']}
# {'names': ['SrMnO3']}
# {'names': ['LMO']}
# {'names': ['LaMnO3']}
# {'names': ['Sr2+']}
# {'names': ['Mn–O']}
# {'names': ['peroxide']}
# {'names': ['hydrogen peroxide', 'Hydrogen peroxide']}
# {'names': ['Mn']}
# {'names': ['strontium']}
# {'names': ['Orthorhombic']}
# {'names': ['Mn3+']}
# {'names': ['perovskite']}
# {'names': ['Mn4+']}
# {'names': ['La1−xSrxMnO3', 'LSMO']}
# 5.
# filename: ./papers2\curie_paper112.html
# Title: Evaluation of La1−xSrxMnO3 (0 ≤ x < 0.4) synthesised via a modified sol–gel method as mediators for magnetic fluid hyperthermia
#
# {'names': ['Belfast BT7 1NN'], 'curie_temperatures': [{'value': '89', 'units': '°C'}]}
# ----------------------------
# {'names': ['Dhaka-1205']}
# {'names': ['germanane']}
# {'names': ['calcium digermanide']}
# {'names': ['CaGe2']}
# {'names': ['methyl']}
# {'names': ['H']}
# {'names': ['Pt']}
# {'names': ['Al']}
# {'names': ['C–C']}
# {'names': ['Si']}
# {'names': ['Na']}
# {'names': ['NPT']}
# {'names': ['carbon']}
# {'names': ['germanium']}
# {'names': ['Au']}
# {'names': ['Zigzag']}
# {'names': ['stanene']}
# {'names': ['Li']}
# {'names': ['Ge']}
# {'names': ['silicene']}
# {'names': ['K']}
# {'names': ['graphene', 'Graphene']}
# {'names': ['SW-1']}
# {'names': ['germanene', 'Germanene'], 'roles': ['product'], 'curie_temperatures': [{'value': '33', 'units': 'K'}]}
# 6.
# filename: ./papers2\curie_paper113.html
# Title: Inherent mechanical properties of bilayer germanene coupled by covalent bonding
#
# {'names': ['germanene', 'Germanene'], 'roles': ['product'], 'curie_temperatures': [{'value': '33', 'units': 'K'}]}
# ----------------------------
# {'names': ['CH-3012 Bern']}
# {'names': ['Ba']}
# {'names': ['Ca']}
# {'names': ['rare-earth']}
# {'names': ['transition metals']}
# {'curie_temperatures': [{'value': '400', 'units': 'K'}]}
# {'neel_temperatures': [{'value': '37', 'units': 'K'}]}
# {'names': ['W6+']}
# {'names': ['O']}
# {'names': ['FeO']}
# {'names': ['MoO3']}
# {'names': ['WO3']}
# {'names': ['isooctane']}
# {'names': ['quartz']}
# {'names': ['H2']}
# {'names': ['N2']}
# {'names': ['(NH4)6Mo7O24·4H2O']}
# {'names': ['Fe(NO3)3·9H2O']}
# {'names': ['H2WO4']}
# {'names': ['nitric']}
# {'names': ['citrate']}
# {'names': ['nitrate']}
# {'names': ['nitric acid']}
# {'names': ['ammonia']}
# {'names': ['SrMoO3']}
# {'names': ['Sr2FeMo0.4W0.6O6']}
# {'names': ['Fe3+Mo5+']}
# {'names': ['Fe2+W6+']}
# {'names': ['Sr2+']}
# {'names': ['ferro- / ferrimagnetic']}
# {'curie_temperatures': [{'value': '420–450', 'units': 'K'}]}
# {'names': ['ferro-, ferri-']}
# {'curie_temperatures': [{'value': '350', 'units': 'K'}]}
# {'curie_temperatures': [{'value': '420–450', 'units': 'K'}]}
# {'names': ['Sr2FeMo0.2W0.8O6']}
# {'names': ['Sr2FeWO6']}
# {'names': ['Iron']}
# {'names': ['perovskites']}
# {'names': ['Sr2FeMo(1−x)WxO6']}
# {'names': ['oxygen']}
# {'names': ['Fe2+']}
# {'names': ['SrCO3']}
# {'names': ['Sr']}
# {'names': ['ethylene glycol']}
# {'names': ['SrMoO4']}
# {'names': ['Mo6+']}
# {'names': ['citric acid', 'Citric acid']}
# {'names': ['EDTA', 'ethylenediaminetetraacetate']}
# {'names': ['ferro-']}
# {'names': ['H']}
# {'names': ['perovskite', 'DP']}
# {'names': ['Fe3+']}
# {'names': ['Mo5+']}
# {'names': ['Sr2FeMo0.3W0.7O6']}
# {'names': ['Fe']}
# {'names': ['Mo'], 'neel_temperatures': [{'value': '40', 'units': 'K'}, {'value': '37–40', 'units': 'K'}]}
# 7.
# filename: ./papers2\curie_paper118.html
# Title: Sol gel and ceramic synthesis of Sr2FeMo1−xWxO6 (0 ≤ x ≤ 1) double perovskites series
#
# {'names': ['Mo'], 'neel_temperatures': [{'value': '40', 'units': 'K'}, {'value': '37–40', 'units': 'K'}]}
# ----------------------------
# {'names': ['Zaragoza 50006']}
# {'names': ['CICECO']}
# {'names': ['Aveiro 3810-193']}
# {'names': ['gallium-doped ε-iron oxide']}
# {'names': ['cobalt ferrite']}
# {'names': ['iron']}
# {'names': ['gallium-substituted ε-iron oxide']}
# {'names': ['ε-iron oxide']}
# {'names': ['ferrites']}
# {'names': ['cobalt ferrites']}
# {'names': ['copper']}
# {'names': ['H C']}
# {'names': ['Fe(NO3)3']}
# {'names': ['Ga(NO3)3']}
# {'names': ['tetraethoxysilane', 'TEOS']}
# {'names': ['Fe']}
# {'names': ['SiO2']}
# {'names': ['NaOH']}
# {'names': ['tetramethylammonium hydroxide', 'TMAH']}
# {'names': ['iron oxide']}
# {'names': ['CSIC']}
# {'names': ['cobalt']}
# {'names': ['gallium', 'Gallium']}
# {'names': ['γ-Fe2O3']}
# {'names': ['ε-GaxFe2−xO3']}
# {'names': ['Ga']}
# {'names': ['ε-Fe2O3']}
# ----------------------------
# {'names': ['Kasserine']}
# {'names': ['O']}
# {'names': ['Cedex']}
# {'names': ['orthorhombic Pr0.8Na0.2MnO3']}
# {'curie_temperatures': [{'value': '115', 'units': 'K'}]}
# {'names': ['RAMnO3']}
# {'names': ['La']}
# {'names': ['Nd']}
# {'names': ['Na']}
# {'names': ['Cs']}
# {'names': ['perovskites']}
# {'names': ['acrylamide']}
# {'names': ['La0.8Na0.2MnO3']}
# {'names': ['Li']}
# {'names': ['Nd0.8Na0.2MnO3 manganite']}
# {'names': ['sodium doped praseodymium manganite']}
# {'names': ['Na2CO3']}
# {'names': ['MnO2']}
# {'names': ['nitrates']}
# {'names': ['monohydrate citric acid']}
# {'names': ['ethylene glycol']}
# {'names': ['silver']}
# {'names': ['Pr0.6Ca0.4MnO3']}
# {'names': ['Pr1.xNaxMnO3']}
# {'names': ['Nd0.5Ca0.5MnO3']}
# {'names': ['Ca1−xCexMnO3']}
# {'names': ['TCO']}
# {'names': ['ferrite']}
# {'names': ["ΔZ ' = Z'low − Z'high"]}
# {'names': ['Mn3+']}
# {'names': ['Mn4+']}
# {'names': ['oxygen']}
# {'names': ['Mn']}
# {'names': ['sodium doped praseodymium manganites'], 'roles': ['product'], 'curie_temperatures': [{'value': '115', 'units': 'K'}]}
# {'names': ['Na-doped manganites']}
# {'names': ['Nd0.8Na0.2MnO3']}
# {'names': ['sodium']}
# {'names': ['nitric acid']}
# {'names': ['H']}
# {'names': ['Perovskite', 'perovskite']}
# {'names': ['oxides']}
# {'names': ['CO']}
# {'names': ['K']}
# {'names': ['manganite']}
# {'names': ['Pr0.8Na0.2MnO3']}
# 9.
# filename: ./papers2\neel_paper218.html
# Title: Structural, magnetic, electrical and dielectric properties of Pr0.8Na0.2MnO3 manganite
#
# {'names': ['sodium doped praseodymium manganites'], 'roles': ['product'], 'curie_temperatures': [{'value': '115', 'units': 'K'}]}
# ----------------------------
# {'names': ['K. Hlil']}
# {'names': ['Dhahri.ahmad']}
# {'names': ['Tel']}
# {'names': ['Aωn']}
# {'names': ['Sr0.5Ca0.5TiO3']}
# {'names': ['Ru']}
# {'names': ['Fe']}
# {'names': ['Ti']}
# {'names': ['manganese oxides']}
# {'names': ['perovskites']}
# {'names': ['La1−xCaxMnO3']}
# {'names': ['La1−xSrxMnO3']}
# {'names': ['La1−xAxMn1−yFeyO3']}
# {'names': ['La0.5Ca0.5−xAgxMnO3']}
# {'names': ['RMnO3']}
# {'names': ['Eu']}
# {'names': ['Tb']}
# {'names': ['Mn3+–Mn4+']}
# {'names': ['Ni']}
# {'names': ['Mg']}
# {'names': ['Al']}
# {'names': ['Re1−xMxMnO3']}
# {'names': ['Nd']}
# {'names': ['Sm']}
# {'names': ['Pb']}
# {'names': ['Ba']}
# {'names': ['Ca']}
# {'names': ['La0.6Gd0.1Sr0.3MnO3']}
# {'names': ['La0.7Sr0.3MnO3']}
# {'names': ['lanthanum']}
# {'names': ['gadolinium']}
# {'curie_temperatures': [{'value': '378', 'units': 'K'}]}
# {'names': ['silicate']}
# {'names': ['La(NO3)3·6H2O']}
# {'names': ['Sr(NO3)2·6H2O']}
# {'names': ['Mn(NO3)2·4H2O']}
# {'names': ['Gd(OOCCH3)3·xH2O']}
# {'names': ['ethylene glycol']}
# {'names': ['graphite']}
# {'names': ['nitrogen']}
# {'names': ['Typical La']}
# {'names': ['Cationic Gd']}
# {'names': ['EDX Si']}
# {'names': ['O(2)']}
# {'names': ['Density(theor.)']}
# {'names': ['(O1)x']}
# {'names': ['(O2)x']}
# {'names': ['dMn–O1']}
# {'names': ['θMn–O1–Mn']}
# {'names': ['dMn–O2']}
# {'names': ['θMn–O2–Mn']}
# {'names': ['〈θMn–O–Mn〉']}
# {'names': ['Ga']}
# {'names': ['Co']}
# {'names': ['Cr']}
# {'names': ['oxygen']}
# {'names': ['manganese']}
# {'names': ['Citric acid', 'citric acid']}
# {'names': ['indium']}
# {'names': ['perovskite', 'Perovskite']}
# {'names': ['silicon']}
# {'names': ['manganite']}
# {'names': ['Mn3+']}
# {'names': ['Mn4+']}
# {'names': ['Sr']}
# {'names': ['La']}
# {'names': ['Gd']}
# {'names': ['Si']}
# {'names': ['Mn']}
# ----------------------------
# {'names': ['C9RA03494C']}
# {'names': ['K. Hlil']}
# {'names': ['oumezzine']}
# {'names': ['B–O–B']}
# {'names': ['R1−xAxMnO3']}
# {'names': ['lanthanum']}
# {'names': ['Barium']}
# {'names': ['θMn–O']}
# {'names': ['manganite oxides']}
# {'names': ['perovskite oxides']}
# {'names': ['transition metal']}
# {'names': ['La(NO3)3·6H2O']}
# {'names': ['Pr(NO3)3·6H2O']}
# {'names': ['Ba(NO3)2']}
# {'names': ['Mn(NO3)2·4H2O']}
# {'names': ['citric acid', 'CA']}
# {'names': ['ethylene glycol', 'EG']}
# {'names': ['Pro']}
# {'names': ['potassium iodide']}
# {'names': ['2 M hydrochloric acid']}
# {'names': ['Liberated iodine']}
# {'names': ['sodium thiosulfate']}
# {'names': ['O2−']}
# {'names': ['Diamond']}
# {'names': ['dMn − O']}
# {'names': ['O']}
# {'names': ['ABO3 perovskite']}
# {'names': ['4A2u + 4Eg + 6Eu']}
# {'curie_temperatures': [{'value': '309', 'units': 'K'}]}
# {'names': ['Mn 3d and O 2p']}
# {'names': ['rPr3+']}
# {'names': ['N']}
# {'names': ['Gd']}
# {'names': ['Mn3+–O2−–Mn4+']}
# {'names': ['lanthanum manganite']}
# {'names': ['La1−x BaxMnO3']}
# {'names': ['Ba2+']}
# {'names': ['dMn–O']}
# {'names': ['Mn–O –']}
# {'names': ['Ba']}
# {'names': ['nitrates']}
# {'names': ['Cu']}
# {'names': ['θ(Mn–O–Mn )']}
# {'names': ['K']}
# {'names': ['manganite', 'Manganite']}
# {'names': ['La']}
# {'names': ['Mn–O']}
# {'names': ['praseodymium', 'Praseodymium']}
# {'names': ['Mn']}
# {'names': ['La3+']}
# {'names': ['H']}
# {'names': ['perovskite']}
# {'names': ['Mn3+']}
# {'names': ['Mn4+']}
# {'names': ['oxygen', 'Oxygen']}
# {'names': ['T']}
# {'names': ['Pr3+']}
# ----------------------------
# {'names': ['H']}
# {'names': ['azobenzenes']}
# {'names': ['acrylates']}
# {'names': ['acetone']}
# {'names': ['propanol-2']}
# {'names': ['ozone']}
# {'names': ['cis–trans azobenzene']}
# {'names': ['dichloromethane', 'Dichloromethane']}
# {'names': ['azo-LCN']}
# {'names': ['azobenzene']}
# ----------------------------
# {'names': ['cobalt ferrite–graphene oxide']}
# {'names': ['polyaniline']}
# {'names': ['nickel ferrite']}
# {'names': ['Ammonium hydroxide']}
# {'names': ['nickel nitrate']}
# {'names': ['Ni(NO3)2·6H2O']}
# {'names': ['zinc nitrate']}
# {'names': ['Zn(NO3)2·6H2O']}
# {'names': ['ferric nitrate']}
# {'names': ['Fe(NO3)3·9H2O']}
# {'names': ['cobalt nitrate']}
# {'names': ['Co(NO3)2·6H2O']}
# {'names': ['Nitrate']}
# {'names': ['metal nitrate']}
# {'names': ['ammonia']}
# {'names': ['aCH2']}
# {'names': ['sCH2']}
# {'names': ['carbonyl']}
# {'names': ['C–N']}
# {'names': ['Co0.7Zn0.3Fe2O4 ferrite']}
# {'names': ['Ni']}
# {'names': ['Fe3+']}
# {'names': ['Zn ferrite']}
# {'names': ['NZFO ferrite']}
# {'names': ['CZFO ferrite']}
# {'names': ['S-parameters']}
# {'names': ['Co0.2Ni0.4Zn0.4Fe2O4']}
# {'names': ['CoFe2O4']}
# {'names': ['MnZn ferrite']}
# {'names': ['epoxy']}
# {'names': ['polyester']}
# {'names': ['FeNi']}
# {'names': ['NiO']}
# {'names': ['metal oxide']}
# {'names': ['Zinc doped nickel ferrite']}
# {'names': ['C–C']}
# {'names': ['cobalt']}
# {'names': ['citric acid']}
# {'names': ['DMF', 'dimethylformamide']}
# {'names': ['graphite']}
# {'names': ['C–H']}
# {'names': ['C–O']}
# {'names': ['hydroxyl']}
# {'names': ['C–O–C']}
# {'names': ['O–H']}
# {'names': ['CO', 'Co']}
# {'names': ['Zn']}
# {'names': ['H']}
# {'names': ['SER']}
# {'names': ['NiFe2O4']}
# {'names': ['Fe3O4']}
# {'names': ['graphene']}
# {'names': ['C–OH']}
# {'names': ['zinc', 'Zinc']}
# {'names': ['nickel']}
# {'names': ['cobalt ferrite']}
# {'names': ['ferrites']}
# {'names': ['graphene oxide', 'Graphene oxide', 'GO']}
# {'names': ['carbon', 'Carbon']}
# {'names': ['NZFO', 'Ni0.7Zn0.3Fe2O4']}
# {'names': ['CZFO', 'Co0.7Zn0.3Fe2O4']}
# {'names': ['ferrite', 'Ferrite']}
# ----------------------------
# {'names': ['K. Hlil']}
# {'names': ['gadolinium']}
# {'names': ['rare earth']}
# {'names': ['divalent alkali earth']}
# {'names': ['manganese oxides']}
# {'names': ['oxides']}
# {'names': ['nitrate']}
# {'names': ['La(NO3)·6H2O']}
# {'names': ['Ca(NO3)2·4H2O']}
# {'names': ['Mn(NO3)2·6H2O']}
# {'names': ['Sr(NO3)2']}
# {'names': ['Citric acid']}
# {'names': ['ethylene glycol']}
# {'names': ['La, Ca']}
# {'names': ['O2 site']}
# {'names': ['〈θMn–O–Mn〉']}
# {'names': ['Oxide']}
# {'names': ['La']}
# {'names': ['Ca']}
# {'curie_temperatures': [{'value': '304', 'units': 'K'}]}
# {'names': ['M(μ0H,T)']}
# {'names': ['K']}
# {'names': ['La0.8K0.2MnO3']}
# {'names': ['La0.8Na0.2MnO3']}
# {'names': ['∂G']}
# {'names': ['(μ0H)n']}
# {'names': ['2 − 2β − γ']}
# {'names': ['N']}
# {'names': ['C8RA00001H'], 'curie_temperatures': [{'value': '304', 'units': 'K'}]}
# {'names': ['La0.6Ca0.4MnO3']}
# {'names': ['La0.6Sr0.4MnO3']}
# {'names': ['Sr']}
# {'names': ['O']}
# {'names': ['Mn']}
# {'names': ['manganite']}
# {'names': ['perovskite']}
# {'names': ['Gd']}
# {'names': ['Tc'], 'curie_temperatures': [{'value': '0.58±0.04'}]}
# {'names': ['La0.6Ca0.3Sr0.1MnO3']}
# 14.
# filename: ./papers2\neel_paper224.html
# Title: Magnetocaloric study, critical behavior and spontaneous magnetization estimation in La0.6Ca0.3Sr0.1MnO3 perovskite
#
# {'names': ['C8RA00001H'], 'curie_temperatures': [{'value': '304', 'units': 'K'}]}
# {'names': ['Tc'], 'curie_temperatures': [{'value': '0.58±0.04'}]}
# ----------------------------
# {'names': ['K. Hlil']}
# {'names': ['chlorofluorocarbons', 'CFC']}
# {'names': ['hydrochlorofluorocarbons', 'HCFC']}
# {'names': ['Gadolinium']}
# {'names': ['Gd5(Ge1−xSix)4']}
# {'names': ['LaFe13−xSix']}
# {'names': ['manganese oxides']}
# {'names': ['(R1−xMx)MnO3']}
# {'names': ['rare earth']}
# {'names': ['divalent alkali earth']}
# {'curie_temperatures': [{'value': '260', 'units': 'K'}]}
# {'names': ['nitrate']}
# {'names': ['La(NO3)6H2O']}
# {'names': ['Ca(NO3)24H2O']}
# {'names': ['Mn(NO3)26H2O']}
# {'names': ['Sr(NO3)2']}
# {'names': ['Citric acid']}
# {'names': ['ethylene glycol']}
# {'names': ['blue line']}
# {'names': ['S1C0']}
# {'names': ['La, Ca']}
# {'names': ['Sr']}
# {'names': ['O2 site']}
# {'names': ['θMn − O1−Mn']}
# {'names': ['θMn–O2–Mn']}
# {'names': ['ddMn–O2']}
# {'names': ['Cu']}
# {'names': ['silicon']}
# {'names': ['La0.8Sr0.2MnO3']}
# {'names': ['La0.7Ca0.3MnO3']}
# {'names': ['Mn–O and A–O']}
# {'names': ['σ2(Mn–O ) and σ2(A–O )']}
# {'names': ['Ti+1']}
# {'names': ['Ti']}
# {'names': ['(μ0H)n']}
# {'names': ['μ0H(T)']}
# {'names': ['K']}
# {'names': ['Gd']}
# {'names': ['La0.8Ca0.2MnO3']}
# {'names': ['N']}
# {'names': ['oxides La0.6Ca0.4MnO3']}
# {'names': ['perovskite']}
# {'names': ['Mn']}
# {'names': ['H']}
# {'names': ['σ2(Mn–O )']}
# {'names': ['σ2(A–O )']}
# {'names': ['La0.8K0.2MnO3']}
# {'names': ['manganite']}
# {'names': ['La0.6Ca0.4MnO3']}
# {'names': ['La0.6Sr0.4MnO3']}
# ----------------------------
# {'names': ['C6RA28839A']}
# {'names': ['K. Hlil']}
# {'names': ['Monastir-5019']}
# {'names': ['Cedex']}
# {'names': ['Tr1−xAxMnO3']}
# {'names': ['Pb']}
# {'names': ['manganese oxides']}
# {'curie_temperatures': [{'value': '282', 'units': 'K'}]}
# {'names': ['Mn3+–O–Mn4+']}
# {'names': ['Mn3+']}
# {'names': ['Mn4+']}
# {'names': ['oxygen']}
# {'names': ['ρ2T2 + ρ4.5T4.5']}
# {'names': ['ρ4.5T4.5 + ρ5T5']}
# {'names': ['Li']}
# {'names': ['U0H(T)']}
# {'curie_temperatures': [{'value': '282', 'units': 'K'}]}
# {'curie_temperatures': [{'value': '280.501±0.165', 'units': 'K'}]}
# {'curie_temperatures': [{'value': '282.123±0.527', 'units': 'K'}]}
# {'names': ['χ0−1(T) / [ dχ0−1(T) / dT]vs. T']}
# {'curie_temperatures': [{'value': '280.442±0.428', 'units': 'K'}]}
# {'curie_temperatures': [{'value': '281.823±0.413', 'units': 'K'}]}
# {'names': ['K']}
# {'names': ['KF']}
# {'names': ['La0.8Sr0.2MnO3']}
# {'names': ['−Bgη−(α+γ) / 2 + B − η−(α+γ−1)']}
# {'names': ['3D-Heisenberg model']}
# {'names': ['manganite']}
# {'names': ['e–e, e–m, and e–p']}
# {'names': ['Sr']}
# {'names': ['La1−xCaxMnO3']}
# {'names': ['Ca']}
# {'names': ['Ba']}
# {'names': ['μ0H(T)']}
# {'names': ['La0.8Ba0.1Ca0.1MnO3']}
# ----------------------------
# {'names': ['K. Hlil']}
# {'names': ['(RE1−xAx)MnO3']}
# {'names': ['rare earth']}
# {'names': ['lanthanum manganites']}
# {'names': ['strontium']}
# {'names': ['Nd(NO3)·6H2O']}
# {'names': ['Sr(NO3)2']}
# {'names': ['Mn(NO3)2·6H2O']}
# {'names': ['glycine']}
# {'names': ['C2H5NO2']}
# {'names': ['citric acid']}
# {'names': ['C6H8O7']}
# {'names': ['ethylene glycol']}
# {'names': ['C2H6O2']}
# {'names': ['〈θMn–O–Mn〉']}
# {'names': ['Cu']}
# {'names': ['Nd']}
# {'names': ['Sr']}
# {'names': ['Mn']}
# {'names': ['La0.6Sr0.4MnO3']}
# {'names': ['Nd0.7Sr0.3MnO3']}
# {'names': ['MS(T < TC,μ0H → 0 ) = M0|ε|β']}
# {'names': ['TC,μ0H']}
# {'names': ['3D-Heisenberg model']}
# {'names': ['O']}
# {'names': ['manganite']}
# {'names': ['Perovskite', 'perovskite']}
# {'names': ['gadolinium']}
# {'names': ['Neodymium', 'neodymium']}
# {'names': ['nitrate']}
# {'names': ['blue line']}
# {'names': ['TCO']}
# {'names': ['Gd']}
# {'names': ['K']}
# {'names': ['KF'], 'curie_temperatures': [{'value': '100'}]}
# {'names': ['CO']}
# {'names': ['NSMO-AC']}
# {'names': ['Nd0.6Sr0.4MnO3']}
# 17.
# filename: ./papers2\neel_paper227.html
# Title: Impact of synthesis route on structural, magnetic, magnetocaloric and critical behavior of Nd0.6Sr0.4MnO3 manganite
#
# {'names': ['KF'], 'curie_temperatures': [{'value': '100'}]}
# ----------------------------
# {'names': ['Cedex']}
# {'names': ['Ln = GdIII1']}
# {'names': ['ErIII4']}
# {'names': ['[Mn12O12(OCR)16(H2O)4]']}
# {'names': ['mononuclear lanthanide']}
# {'names': ['terbium(III)']}
# {'names': ['4f–4f']}
# {'names': ['– 4f heterometallic SMMs']}
# {'names': ['dimeric lanthanide']}
# {'names': ['Gd(NO3)3·6H2O']}
# {'names': ['Ln(NO3)3·xH2O']}
# {'names': ['Dy(NO3)3·5H2O']}
# {'names': ['Y(NO3)3·5H2O']}
# {'names': ['Y1.8Dy0.2Ga4C94 H93N15O31 : C']}
# {'names': ['graphite']}
# {'names': ['Paratone-N']}
# {'names': ['nitrogen']}
# {'names': ['Saturn']}
# {'names': ['Cu']}
# {'labels': ['4'], 'roles': ['data for', 'compounds']}
# {'labels': ['5'], 'roles': ['data for', 'compounds']}
# {'names': ['non-hydrogen']}
# {'names': ['[GaIII4LnIII2(shi3−)4(Hshi2−)2(H2shi−)2(C5H5N)4(CH3OH)(H2O)]']}
# {'names': ['Σ[w(Fo2 − Fc2)2 ]']}
# {'names': ['Ga4Tb2C94H93N15O31']}
# {'names': ['Ga4Dy2C94H93N15O31']}
# {'names': ['Ga4Er2C93H91N15O31']}
# {'names': ['Ga4Y2C94H93N15O31']}
# {'names': ['e− Å−3']}
# {'names': ['lutetium']}
# {'names': ['Ln']}
# {'names': ['Chibotaru A']}
# {'names': ['9-MC-3']}
# {'names': ['Ln(NO3)·xH2O']}
# {'names': ['[Ga4Ln2(shi3−)4(Hshi2−)2(H2shi)2(C5H5N)4(CH3OH)(H2O)]·3C5H5N·2CH3OH·3H2O']}
# {'names': ['C2']}
# {'names': ['di-lanthanide']}
# {'names': ['carbonyl'], 'labels': ['O1']}
# {'names': ['carbonyl'], 'labels': ['O7']}
# {'names': ['phenoxide oxygens']}
# {'names': ['Dy2(μ2-OR)2']}
# {'names': ['8-coordinate']}
# {'names': ['H = −JSGd1 × SGd2 + gßHzSz']}
# {'names': ['Tb–Tb']}
# {'names': ['2|J|MS2']}
# {'names': ['Er2O2 plane']}
# {'names': ['oxime']}
# {'names': ['ferro- |− − >']}
# {'names': ['χ′′ = f(T)']}
# {'names': ['diamond']}
# {'names': ['Ln2O2']}
# {'names': ['H2shi−']}
# {'names': ['phenol']}
# {'names': ['oxygens']}
# {'names': ['LnOOLn plane']}
# {'names': ['[Ga4Ln2(shi3−)4(Hshi2−)2(H2shi−)2(C5H5N)4(CH3OH)x(H2O)x]·xC5H5N·xCH3OH·xH2O']}
# {'names': ['transition-metal']}
# {'names': ['H2O']}
# {'names': ['Mo']}
# {'labels': ['1'], 'roles': ['data for', 'compound', 'compounds']}
# {'labels': ['2'], 'roles': ['data for', 'compound', 'complex']}
# {'names': ['Hydrogen']}
# {'names': ['eicosane']}
# {'names': ['gadolinium']}
# {'names': ['hydroximate oxygens', 'Hydroximate oxygens'], 'labels': ['O2']}
# {'names': ['hydroximate']}
# {'names': ['Gd']}
# {'names': ['Ln2Ga4'], 'roles': ['product']}
# {'names': ['O']}
# {'names': ['Er']}
# {'names': ['Ga(NO3)3·xH2O']}
# {'names': ['H']}
# {'names': ['− 21 ≤ l ≤']}
# {'names': ['salicylhydroxamic acid', 'Salicylhydroxamic acid']}
# {'names': ['pyridine', 'Pyridine']}
# {'names': ['methanol']}
# {'names': ['Tb']}
# {'labels': ['6'], 'roles': ['compound', 'data for']}
# {'names': ['oxygen']}
# {'names': ['N']}
# {'labels': ['3'], 'roles': ['compound', 'data for', 'compounds', 'complex', 'data of', 'derivative']}
# {'names': ['lanthanide']}
# ----------------------------
# {'names': ['PA 19104']}
# {'names': ['Sodium alginate']}
# {'names': ['guluronic acid']}
# {'names': ['Ferric chloride hexahydrate, ferrous chloride tetrahydrate']}
# {'names': ['Phosphate']}
# {'names': ['L-glutamine']}
# {'names': ['L glucose']}
# {'names': ['sodium pyruvate']}
# {'names': ['Milli-Q']}
# {'names': ['ferric chloride hexahydrate']}
# {'names': ['ferrous chloride tetrahydrate']}
# {'names': ['N sodium hydroxide']}
# {'names': ['carbon']}
# {'names': ['CO2']}
# {'names': ['Perspex']}
# {'names': ['Pt–Ir']}
# {'names': ['Si']}
# {'names': ['Ca2+']}
# {'names': ['hemi-calcium']}
# {'names': ['tyrosine']}
# {'names': ['Stein']}
# {'names': ['PA 19102']}
# {'names': ['hemicalcium']}
# {'names': ['sodium hydroxide']}
# {'names': ['copper']}
# {'names': ['D-gluconic acid']}
# {'names': ['Drexel']}
# {'names': ['Helmholtz']}
# {'names': ['magnetite', 'Magnetite']}
# {'names': ['calcium']}
# ----------------------------
# Run Time:  330.0552323  seconds

# %%
len(all_extracted_json)
# Out:
# 11

# %%
all_extracted_json
# Out:
# [[{'names': ['NiFe2O4'],
#    'curie_temperatures': [{'value': '883', 'units': 'K'}]},
#   {'doi': '10.1039/d0ra05522k',
#    'publisher': 'Royal Society of Chemistry',
#    'title': 'Magnetic and spectroscopic properties of Ni–Zn–Al ferrite spinel: from the nanoscale to microscale',
#    'authors': ['Jalel Massoudi',
#     'Mourad Smari',
#     'Kamel Nouri',
#     'Essebti Dhahri',
#     'Kamel Khirouni',
#     'Sylvain Bertaina',
#     'Lotfi Bessais',
#     'El Kebir Hlil',
#     'Jalel Massoudi',
#     'Mourad Smari',
#     'Kamel Nouri',
#     'Essebti Dhahri',
#     'Kamel Khirouni',
#     'Sylvain Bertaina',
#     'Lotfi Bessais',
#     'El Kebir Hlil'],
#    'filename': './papers2\\curie_paper1.html'}],
#  [{'names': ['BaFe12O19'],
#    'curie_temperatures': [{'value': '740', 'units': 'K'}]},
#   {'doi': '10.1039/c7dt01708a',
#    'publisher': 'Royal Society of Chemistry',
#    'title': 'Investigation into the structural features and microwave absorption of doped barium hexaferrites',
#    'authors': ['S. V. Trukhanov',
#     'A. V. Trukhanov',
#     'V. G. Kostishyn',
#     'L. V. Panina',
#     'An. V. Trukhanov',
#     'V. A. Turchenko',
#     'D. I. Tishkevich',
#     'E. L. Trukhanova',
#     'O. S. Yakovenko',
#     'L. Yu. Matzui',
#     'S. V. Trukhanov',
#     'A. V. Trukhanov',
#     'V. G. Kostishyn',
#     'L. V. Panina',
#     'An. V. Trukhanov',
#     'V. A. Turchenko',
#     'D. I. Tishkevich',
#     'E. L. Trukhanova',
#     'O. S. Yakovenko',
#     'L. Yu. Matzui'],
#    'filename': './papers2\\curie_paper10.html'}],
#  [{'names': ['plumbene'],
#    'roles': ['product'],
#    'curie_temperatures': [{'value': '300', 'units': 'K'}]},
#   {'doi': '10.1039/c9ra10337f',
#    'publisher': 'Royal Society of Chemistry',
#    'title': 'Magnetic properties of 3d transition metal (Sc–Ni) doped plumbene',
#    'authors': ['Daniel Hashemi',
#     'Hideo Iizuka',
#     'Daniel Hashemi',
#     'Hideo Iizuka'],
#    'filename': './papers2\\curie_paper101.html'}],
#  [{'names': ['Ni', '[NH2(CH3)2][CrIIINiII(HCOO)6]'],
#    'labels': ['2'],
#    'roles': ['complex', 'data for'],
#    'curie_temperatures': [{'value': '15.3'}]},
#   {'names': ['[NH2(CH3)2][CrIIIFeII(HCOO)6]', 'Fe'],
#    'labels': ['1'],
#    'roles': ['complex', 'data for']},
#   {'doi': '10.1039/c7ra08695d',
#    'publisher': 'Royal Society of Chemistry',
#    'title': 'Study of the relationship between magnetic field and dielectric properties in two ferromagnetic complexes',
#    'authors': ['Li Yang',
#     'Jing Li',
#     'Tian-Cheng Pu',
#     'Ming Kong',
#     'Jing Zhang',
#     'You Song',
#     'Li Yang',
#     'Jing Li',
#     'Tian-Cheng Pu',
#     'Ming Kong',
#     'Jing Zhang',
#     'You Song'],
#    'filename': './papers2\\curie_paper106.html'}],
#  [{'names': ['Nb-doped lead zirconate titanate',
#     'Lead zirconate titanate',
#     'PZTN',
#     'lead zirconate titanate'],
#    'curie_temperatures': [{'value': '∼38', 'units': '°C'}]},
#   {'names': ['hydrogen', 'Hydrogen'],
#    'labels': ['H2'],
#    'roles': ['product'],
#    'curie_temperatures': [{'value': '∼39', 'units': '°C'},
#     {'value': '100', 'units': '°C'},
#     {'value': '∼38', 'units': '°C'}]},
#   {'doi': '10.1039/d1na00013f',
#    'publisher': 'Royal Society of Chemistry',
#    'title': 'Polarisation tuneable piezo-catalytic activity of Nb-doped PZT with low Curie temperature for efficient CO2 reduction and H2 generation',
#    'authors': ['Yan Zhang',
#     'Pham Thi Thuy Phuong',
#     'Nguyen Phuc Hoang Duy',
#     'Eleanor Roake',
#     'Hamideh Khanbareh',
#     'Margaret Hopkins',
#     'Xuefan Zhou',
#     'Dou Zhang',
#     'Kechao Zhou',
#     'Chris Bowen',
#     'Yan Zhang',
#     'Pham Thi Thuy Phuong',
#     'Nguyen Phuc Hoang Duy',
#     'Eleanor Roake',
#     'Hamideh Khanbareh',
#     'Margaret Hopkins',
#     'Xuefan Zhou',
#     'Dou Zhang',
#     'Kechao Zhou',
#     'Chris Bowen'],
#    'filename': './papers2\\curie_paper11.html'}],
#  [{'names': ['Belfast BT7 1NN'],
#    'curie_temperatures': [{'value': '89', 'units': '°C'}]},
#   {'doi': '10.1039/c5ce01890k',
#    'publisher': 'Royal Society of Chemistry',
#    'title': 'Evaluation of La1−xSrxMnO3 (0 ≤ x < 0.4) synthesised via a modified sol–gel method as mediators for magnetic fluid hyperthermia',
#    'authors': ['K. McBride',
#     'J. Cook',
#     'S. Gray',
#     'S. Felton',
#     'L. Stella',
#     'D. Poulidi',
#     'K. McBride',
#     'J. Cook',
#     'S. Gray',
#     'S. Felton',
#     'L. Stella',
#     'D. Poulidi'],
#    'filename': './papers2\\curie_paper112.html'}],
#  [{'names': ['germanene', 'Germanene'],
#    'roles': ['product'],
#    'curie_temperatures': [{'value': '33', 'units': 'K'}]},
#   {'doi': '10.1039/c9ra06003k',
#    'publisher': 'Royal Society of Chemistry',
#    'title': 'Inherent mechanical properties of bilayer germanene coupled by covalent bonding',
#    'authors': ['Mahmuda Raakib Arshee',
#     'Saqeeb Adnan',
#     'Mohammad Motalab',
#     'Pritom Bose',
#     'Mahmuda Raakib Arshee',
#     'Saqeeb Adnan',
#     'Mohammad Motalab',
#     'Pritom Bose'],
#    'filename': './papers2\\curie_paper113.html'}],
#  [{'names': ['Mo'],
#    'neel_temperatures': [{'value': '40', 'units': 'K'},
#     {'value': '37–40', 'units': 'K'}]},
#   {'doi': '10.1039/c6ra03923e',
#    'publisher': 'Royal Society of Chemistry',
#    'title': 'Sol gel and ceramic synthesis of Sr2FeMo1−xWxO6 (0 ≤ x ≤ 1) double perovskites series',
#    'authors': ['M. Iranmanesh',
#     'M. Lingg',
#     'M. Stir',
#     'J. Hulliger',
#     'M. Iranmanesh',
#     'M. Lingg',
#     'M. Stir',
#     'J. Hulliger'],
#    'filename': './papers2\\curie_paper118.html'}],
#  [{'names': ['sodium doped praseodymium manganites'],
#    'roles': ['product'],
#    'curie_temperatures': [{'value': '115', 'units': 'K'}]},
#   {'doi': '10.1039/c9ra05414f',
#    'publisher': 'Royal Society of Chemistry',
#    'title': 'Structural, magnetic, electrical and dielectric properties of Pr0.8Na0.2MnO3 manganite',
#    'authors': ['I. Ouni',
#     'H. Ben Khlifa',
#     "R. M'nassri",
#     'Muaffaq M. Nofal',
#     'H. Rahmouni',
#     'W. Cheikhrouhou',
#     'N. Chniba-Boudjada',
#     'K. Khirouni',
#     'A. Cheikhrouhou',
#     'I. Ouni',
#     'H. Ben Khlifa',
#     "R. M'nassri",
#     'Muaffaq M. Nofal',
#     'H. Rahmouni',
#     'W. Cheikhrouhou',
#     'N. Chniba-Boudjada',
#     'K. Khirouni',
#     'A. Cheikhrouhou'],
#    'filename': './papers2\\neel_paper218.html'}],
#  [{'names': ['C8RA00001H'],
#    'curie_temperatures': [{'value': '304', 'units': 'K'}]},
#   {'names': ['Tc'], 'curie_temperatures': [{'value': '0.58±0.04'}]},
#   {'doi': '10.1039/c8ra00001h',
#    'publisher': 'Royal Society of Chemistry',
#    'title': 'Magnetocaloric study, critical behavior and spontaneous magnetization estimation in La0.6Ca0.3Sr0.1MnO3 perovskite',
#    'authors': ['M. Jeddi',
#     'H. Gharsallah',
#     'M. Bejar',
#     'M. Bekri',
#     'E. Dhahri',
#     'E. K. Hlil',
#     'M. Jeddi',
#     'H. Gharsallah',
#     'M. Bejar',
#     'M. Bekri',
#     'E. Dhahri',
#     'E. K. Hlil'],
#    'filename': './papers2\\neel_paper224.html'}],
#  [{'names': ['KF'], 'curie_temperatures': [{'value': '100'}]},
#   {'doi': '10.1039/d0ra10118d',
#    'publisher': 'Royal Society of Chemistry',
#    'title': 'Impact of synthesis route on structural, magnetic, magnetocaloric and critical behavior of Nd0.6Sr0.4MnO3 manganite',
#    'authors': ['M. Jeddi',
#     'J. Massoudi',
#     'H. Gharsallah',
#     'Sameh I. Ahmed',
#     'E. Dhahri',
#     'E. K. Hlil',
#     'M. Jeddi',
#     'J. Massoudi',
#     'H. Gharsallah',
#     'Sameh I. Ahmed',
#     'E. Dhahri',
#     'E. K. Hlil'],
#    'filename': './papers2\\neel_paper227.html'}]]

# %%
#print(""" The obtained Curie temperature value, TC, of the samples are lower than that of polycrystalline NiFe2O4 (TC = 883 K)32 and NiFe2O4 nanoparticles (TC > 800 K)69 as well as Ni0.6Zn0.4Fe2O4 nanoparticles (TC = 663 K) reported by Gawas et al. """)

# %%
import re

def convert_rawdata(raw_data):
    """
    Data tables created with columns including Property, Name, Raw_value, Raw_unit, Value, Unit,
    DOI, Title, Journal, Date, Specifier, Correctness, Tag, Info, and Warning.
    """
    result = list();
    
    #check if there's metadata
    meta = False
    meta_keys = ["doi", "publisher", "authors", "filename", "title"]
    for key in meta_keys:
        if key in raw_data[-1]:
            meta = True
            
    for i in range( len(raw_data)-1 ):

        keys = list(raw_data[i].keys())
        name = ", ".join(raw_data[i]["names"])

        if("curie_temperatures" in keys):
            for extracted_data in raw_data[i]["curie_temperatures"]:
                new_dict = collections.defaultdict(str)
                new_dict["Names"] = name
                new_dict["Type"] = "Curie"
                if(not "value" in extracted_data):
                    continue
                new_dict["Extracted Value"] = extracted_data["value"]
                if("units" in extracted_data):
                    new_dict["Extracted Unit"] = extracted_data["units"]
                    
                new_temp = normalise_temperature(extracted_data)
                if( new_temp != None ):
                    new_dict.update( new_temp )

                if(meta == True):
                    new_dict.update(raw_data[-1]) # metadata
                result.append(new_dict)
                new_dict['Correctness'] = 'None'
                new_dict['Tag'] = 'CDE'

        if("neel_temperatures" in keys):
            for extracted_data in raw_data[i]["neel_temperatures"]:
                new_dict = collections.defaultdict(str)
                new_dict["Names"] = name
                new_dict["Type"] = "Neel"
                if(not "value" in extracted_data):
                    continue
                new_dict["Extracted Value"] = extracted_data["value"]
                if("units" in extracted_data):
                    new_dict["Extracted Unit"] = extracted_data["units"]
                
                new_temp = normalise_temperature(extracted_data)
                if( new_temp != None ):
                    new_dict.update( new_temp )
                
                if(meta == True):
                    new_dict.update(raw_data[-1])
                result.append(new_dict)
                new_dict['Correctness'] = 'None'
                new_dict['Tag'] = 'CDE'
            
    return result

def normalise_temperature(data):
    
    try:
    
        res = dict()
        try:
            unit = str( data["units"] )
        except:
            return None

        if(data['units'] == 'K'):
            res["Normalised value"] = data["value"]
            res["Normalised units"] = 'K'
            return res

        match = re.search("c|C", data["units"])
        if(match != None): # C to K
            if('∼' in data['value']):
                front = False
                if( data['value'][0] == '∼'):
                    front = True
                divide = data["value"].split('∼')
                if(front):
                    divide = divide[1:]
                for i in range(len(divide)):
                    divide[i] = str(float(divide[i])+273)

                res["Normalised value"] = "~"+"~".join(divide)
                res["Normalised units"] = 'K'
            elif('-' in data['value'] and not data['value'][0] == '-'):
                divide = data["value"].split('-')
                for i in range(len(divide)):
                    divide[i] = str(float(divide[i])+273)
                res["Normalised value"] = "-".join(divide)
                res["Normalised units"] = 'K'
            else:
                res["Normalised value"] = float(data["value"])+273
                res["Normalised units"] = 'K'
            return res
    except:
        return None

     
    
    return None

# %%
database = list()
for raw_data in all_extracted_json:
    #if(not "names" in raw_data):
    #   continue
    print(raw_data)
    temp = convert_rawdata(raw_data)
    #print(temp)
    for clean_data in temp:
        database.append(clean_data)
        
database = pd.DataFrame(database)
database
# Out:
# [{'names': ['NiFe2O4'], 'curie_temperatures': [{'value': '883', 'units': 'K'}]}, {'doi': '10.1039/d0ra05522k', 'publisher': 'Royal Society of Chemistry', 'title': 'Magnetic and spectroscopic properties of Ni–Zn–Al ferrite spinel: from the nanoscale to microscale', 'authors': ['Jalel Massoudi', 'Mourad Smari', 'Kamel Nouri', 'Essebti Dhahri', 'Kamel Khirouni', 'Sylvain Bertaina', 'Lotfi Bessais', 'El Kebir Hlil', 'Jalel Massoudi', 'Mourad Smari', 'Kamel Nouri', 'Essebti Dhahri', 'Kamel Khirouni', 'Sylvain Bertaina', 'Lotfi Bessais', 'El Kebir Hlil'], 'filename': './papers2\\curie_paper1.html'}]
# [{'names': ['BaFe12O19'], 'curie_temperatures': [{'value': '740', 'units': 'K'}]}, {'doi': '10.1039/c7dt01708a', 'publisher': 'Royal Society of Chemistry', 'title': 'Investigation into the structural features and microwave absorption of doped barium hexaferrites', 'authors': ['S. V. Trukhanov', 'A. V. Trukhanov', 'V. G. Kostishyn', 'L. V. Panina', 'An. V. Trukhanov', 'V. A. Turchenko', 'D. I. Tishkevich', 'E. L. Trukhanova', 'O. S. Yakovenko', 'L. Yu. Matzui', 'S. V. Trukhanov', 'A. V. Trukhanov', 'V. G. Kostishyn', 'L. V. Panina', 'An. V. Trukhanov', 'V. A. Turchenko', 'D. I. Tishkevich', 'E. L. Trukhanova', 'O. S. Yakovenko', 'L. Yu. Matzui'], 'filename': './papers2\\curie_paper10.html'}]
# [{'names': ['plumbene'], 'roles': ['product'], 'curie_temperatures': [{'value': '300', 'units': 'K'}]}, {'doi': '10.1039/c9ra10337f', 'publisher': 'Royal Society of Chemistry', 'title': 'Magnetic properties of 3d transition metal (Sc–Ni) doped plumbene', 'authors': ['Daniel Hashemi', 'Hideo Iizuka', 'Daniel Hashemi', 'Hideo Iizuka'], 'filename': './papers2\\curie_paper101.html'}]
# [{'names': ['Ni', '[NH2(CH3)2][CrIIINiII(HCOO)6]'], 'labels': ['2'], 'roles': ['complex', 'data for'], 'curie_temperatures': [{'value': '15.3'}]}, {'names': ['[NH2(CH3)2][CrIIIFeII(HCOO)6]', 'Fe'], 'labels': ['1'], 'roles': ['complex', 'data for']}, {'doi': '10.1039/c7ra08695d', 'publisher': 'Royal Society of Chemistry', 'title': 'Study of the relationship between magnetic field and dielectric properties in two ferromagnetic complexes', 'authors': ['Li Yang', 'Jing Li', 'Tian-Cheng Pu', 'Ming Kong', 'Jing Zhang', 'You Song', 'Li Yang', 'Jing Li', 'Tian-Cheng Pu', 'Ming Kong', 'Jing Zhang', 'You Song'], 'filename': './papers2\\curie_paper106.html'}]
# [{'names': ['Nb-doped lead zirconate titanate', 'Lead zirconate titanate', 'PZTN', 'lead zirconate titanate'], 'curie_temperatures': [{'value': '∼38', 'units': '°C'}]}, {'names': ['hydrogen', 'Hydrogen'], 'labels': ['H2'], 'roles': ['product'], 'curie_temperatures': [{'value': '∼39', 'units': '°C'}, {'value': '100', 'units': '°C'}, {'value': '∼38', 'units': '°C'}]}, {'doi': '10.1039/d1na00013f', 'publisher': 'Royal Society of Chemistry', 'title': 'Polarisation tuneable piezo-catalytic activity of Nb-doped PZT with low Curie temperature for efficient CO2 reduction and H2 generation', 'authors': ['Yan Zhang', 'Pham Thi Thuy Phuong', 'Nguyen Phuc Hoang Duy', 'Eleanor Roake', 'Hamideh Khanbareh', 'Margaret Hopkins', 'Xuefan Zhou', 'Dou Zhang', 'Kechao Zhou', 'Chris Bowen', 'Yan Zhang', 'Pham Thi Thuy Phuong', 'Nguyen Phuc Hoang Duy', 'Eleanor Roake', 'Hamideh Khanbareh', 'Margaret Hopkins', 'Xuefan Zhou', 'Dou Zhang', 'Kechao Zhou', 'Chris Bowen'], 'filename': './papers2\\curie_paper11.html'}]
# [{'names': ['Belfast BT7 1NN'], 'curie_temperatures': [{'value': '89', 'units': '°C'}]}, {'doi': '10.1039/c5ce01890k', 'publisher': 'Royal Society of Chemistry', 'title': 'Evaluation of La1−xSrxMnO3 (0 ≤ x < 0.4) synthesised via a modified sol–gel method as mediators for magnetic fluid hyperthermia', 'authors': ['K. McBride', 'J. Cook', 'S. Gray', 'S. Felton', 'L. Stella', 'D. Poulidi', 'K. McBride', 'J. Cook', 'S. Gray', 'S. Felton', 'L. Stella', 'D. Poulidi'], 'filename': './papers2\\curie_paper112.html'}]
# [{'names': ['germanene', 'Germanene'], 'roles': ['product'], 'curie_temperatures': [{'value': '33', 'units': 'K'}]}, {'doi': '10.1039/c9ra06003k', 'publisher': 'Royal Society of Chemistry', 'title': 'Inherent mechanical properties of bilayer germanene coupled by covalent bonding', 'authors': ['Mahmuda Raakib Arshee', 'Saqeeb Adnan', 'Mohammad Motalab', 'Pritom Bose', 'Mahmuda Raakib Arshee', 'Saqeeb Adnan', 'Mohammad Motalab', 'Pritom Bose'], 'filename': './papers2\\curie_paper113.html'}]
# [{'names': ['Mo'], 'neel_temperatures': [{'value': '40', 'units': 'K'}, {'value': '37–40', 'units': 'K'}]}, {'doi': '10.1039/c6ra03923e', 'publisher': 'Royal Society of Chemistry', 'title': 'Sol gel and ceramic synthesis of Sr2FeMo1−xWxO6 (0 ≤ x ≤ 1) double perovskites series', 'authors': ['M. Iranmanesh', 'M. Lingg', 'M. Stir', 'J. Hulliger', 'M. Iranmanesh', 'M. Lingg', 'M. Stir', 'J. Hulliger'], 'filename': './papers2\\curie_paper118.html'}]
# [{'names': ['sodium doped praseodymium manganites'], 'roles': ['product'], 'curie_temperatures': [{'value': '115', 'units': 'K'}]}, {'doi': '10.1039/c9ra05414f', 'publisher': 'Royal Society of Chemistry', 'title': 'Structural, magnetic, electrical and dielectric properties of Pr0.8Na0.2MnO3 manganite', 'authors': ['I. Ouni', 'H. Ben Khlifa', "R. M'nassri", 'Muaffaq M. Nofal', 'H. Rahmouni', 'W. Cheikhrouhou', 'N. Chniba-Boudjada', 'K. Khirouni', 'A. Cheikhrouhou', 'I. Ouni', 'H. Ben Khlifa', "R. M'nassri", 'Muaffaq M. Nofal', 'H. Rahmouni', 'W. Cheikhrouhou', 'N. Chniba-Boudjada', 'K. Khirouni', 'A. Cheikhrouhou'], 'filename': './papers2\\neel_paper218.html'}]
# [{'names': ['C8RA00001H'], 'curie_temperatures': [{'value': '304', 'units': 'K'}]}, {'names': ['Tc'], 'curie_temperatures': [{'value': '0.58±0.04'}]}, {'doi': '10.1039/c8ra00001h', 'publisher': 'Royal Society of Chemistry', 'title': 'Magnetocaloric study, critical behavior and spontaneous magnetization estimation in La0.6Ca0.3Sr0.1MnO3 perovskite', 'authors': ['M. Jeddi', 'H. Gharsallah', 'M. Bejar', 'M. Bekri', 'E. Dhahri', 'E. K. Hlil', 'M. Jeddi', 'H. Gharsallah', 'M. Bejar', 'M. Bekri', 'E. Dhahri', 'E. K. Hlil'], 'filename': './papers2\\neel_paper224.html'}]
# [{'names': ['KF'], 'curie_temperatures': [{'value': '100'}]}, {'doi': '10.1039/d0ra10118d', 'publisher': 'Royal Society of Chemistry', 'title': 'Impact of synthesis route on structural, magnetic, magnetocaloric and critical behavior of Nd0.6Sr0.4MnO3 manganite', 'authors': ['M. Jeddi', 'J. Massoudi', 'H. Gharsallah', 'Sameh I. Ahmed', 'E. Dhahri', 'E. K. Hlil', 'M. Jeddi', 'J. Massoudi', 'H. Gharsallah', 'Sameh I. Ahmed', 'E. Dhahri', 'E. K. Hlil'], 'filename': './papers2\\neel_paper227.html'}]
#                                                 Names   Type Extracted Value  \
# 0                                             NiFe2O4  Curie             883
# 1                                           BaFe12O19  Curie             740
# 2                                            plumbene  Curie             300
# 3                   Ni, [NH2(CH3)2][CrIIINiII(HCOO)6]  Curie            15.3
# 4   Nb-doped lead zirconate titanate, Lead zircona...  Curie             ∼38
# 5                                  hydrogen, Hydrogen  Curie             ∼39
# 6                                  hydrogen, Hydrogen  Curie             100
# 7                                  hydrogen, Hydrogen  Curie             ∼38
# 8                                     Belfast BT7 1NN  Curie              89
# 9                                germanene, Germanene  Curie              33
# 10                                                 Mo   Neel              40
# 11                                                 Mo   Neel           37–40
# 12               sodium doped praseodymium manganites  Curie             115
# 13                                         C8RA00001H  Curie             304
# 14                                                 Tc  Curie       0.58±0.04
# 15                                                 KF  Curie             100
#
#    Extracted Unit Normalised value Normalised units                 doi  \
# 0               K              883                K  10.1039/d0ra05522k
# 1               K              740                K  10.1039/c7dt01708a
# 2               K              300                K  10.1039/c9ra10337f
# 3             NaN              NaN              NaN  10.1039/c7ra08695d
# 4              °C           ~311.0                K  10.1039/d1na00013f
# 5              °C           ~312.0                K  10.1039/d1na00013f
# 6              °C              373                K  10.1039/d1na00013f
# 7              °C           ~311.0                K  10.1039/d1na00013f
# 8              °C              362                K  10.1039/c5ce01890k
# 9               K               33                K  10.1039/c9ra06003k
# 10              K               40                K  10.1039/c6ra03923e
# 11              K            37–40                K  10.1039/c6ra03923e
# 12              K              115                K  10.1039/c9ra05414f
# 13              K              304                K  10.1039/c8ra00001h
# 14            NaN              NaN              NaN  10.1039/c8ra00001h
# 15            NaN              NaN              NaN  10.1039/d0ra10118d
#
#                      publisher  \
# 0   Royal Society of Chemistry
# 1   Royal Society of Chemistry
# 2   Royal Society of Chemistry
# 3   Royal Society of Chemistry
# 4   Royal Society of Chemistry
# 5   Royal Society of Chemistry
# 6   Royal Society of Chemistry
# 7   Royal Society of Chemistry
# 8   Royal Society of Chemistry
# 9   Royal Society of Chemistry
# 10  Royal Society of Chemistry
# 11  Royal Society of Chemistry
# 12  Royal Society of Chemistry
# 13  Royal Society of Chemistry
# 14  Royal Society of Chemistry
# 15  Royal Society of Chemistry
#
#                                                 title  \
# 0   Magnetic and spectroscopic properties of Ni–Zn...
# 1   Investigation into the structural features and...
# 2   Magnetic properties of 3d transition metal (Sc...
# 3   Study of the relationship between magnetic fie...
# 4   Polarisation tuneable piezo-catalytic activity...
# 5   Polarisation tuneable piezo-catalytic activity...
# 6   Polarisation tuneable piezo-catalytic activity...
# 7   Polarisation tuneable piezo-catalytic activity...
# 8   Evaluation of La1−xSrxMnO3 (0 ≤ x < 0.4) synth...
# 9   Inherent mechanical properties of bilayer germ...
# 10  Sol gel and ceramic synthesis of Sr2FeMo1−xWxO...
# 11  Sol gel and ceramic synthesis of Sr2FeMo1−xWxO...
# 12  Structural, magnetic, electrical and dielectri...
# 13  Magnetocaloric study, critical behavior and sp...
# 14  Magnetocaloric study, critical behavior and sp...
# 15  Impact of synthesis route on structural, magne...
#
#                                               authors  \
# 0   [Jalel Massoudi, Mourad Smari, Kamel Nouri, Es...
# 1   [S. V. Trukhanov, A. V. Trukhanov, V. G. Kosti...
# 2   [Daniel Hashemi, Hideo Iizuka, Daniel Hashemi,...
# 3   [Li Yang, Jing Li, Tian-Cheng Pu, Ming Kong, J...
# 4   [Yan Zhang, Pham Thi Thuy Phuong, Nguyen Phuc ...
# 5   [Yan Zhang, Pham Thi Thuy Phuong, Nguyen Phuc ...
# 6   [Yan Zhang, Pham Thi Thuy Phuong, Nguyen Phuc ...
# 7   [Yan Zhang, Pham Thi Thuy Phuong, Nguyen Phuc ...
# 8   [K. McBride, J. Cook, S. Gray, S. Felton, L. S...
# 9   [Mahmuda Raakib Arshee, Saqeeb Adnan, Mohammad...
# 10  [M. Iranmanesh, M. Lingg, M. Stir, J. Hulliger...
# 11  [M. Iranmanesh, M. Lingg, M. Stir, J. Hulliger...
# 12  [I. Ouni, H. Ben Khlifa, R. M'nassri, Muaffaq ...
# 13  [M. Jeddi, H. Gharsallah, M. Bejar, M. Bekri, ...
# 14  [M. Jeddi, H. Gharsallah, M. Bejar, M. Bekri, ...
# 15  [M. Jeddi, J. Massoudi, H. Gharsallah, Sameh I...
#
#                          filename Correctness  Tag
# 0     ./papers2\curie_paper1.html        None  CDE
# 1    ./papers2\curie_paper10.html        None  CDE
# 2   ./papers2\curie_paper101.html        None  CDE
# 3   ./papers2\curie_paper106.html        None  CDE
# 4    ./papers2\curie_paper11.html        None  CDE
# 5    ./papers2\curie_paper11.html        None  CDE
# 6    ./papers2\curie_paper11.html        None  CDE
# 7    ./papers2\curie_paper11.html        None  CDE
# 8   ./papers2\curie_paper112.html        None  CDE
# 9   ./papers2\curie_paper113.html        None  CDE
# 10  ./papers2\curie_paper118.html        None  CDE
# 11  ./papers2\curie_paper118.html        None  CDE
# 12   ./papers2\neel_paper218.html        None  CDE
# 13   ./papers2\neel_paper224.html        None  CDE
# 14   ./papers2\neel_paper224.html        None  CDE
# 15   ./papers2\neel_paper227.html        None  CDE

# %%
database.to_csv("curie_neel_database_papers2.csv", mode='w')
